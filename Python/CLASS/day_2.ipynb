# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
a = "hi"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 10.2
print(type(a))
# Out:
# <class 'float'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a = 1+2j
print(type(a))
# Out:
# <class 'complex'>

# %%
b1 = 10
b1
# Out:
# 10

# %%
b =float(b1)
b
# Out:
# 10.0
