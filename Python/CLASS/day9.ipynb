# %%
s1 ={ "Hi", "Hello", 5, 6, 7, 8 }
s2 = { 2, 3, 4, 5 }

s1.remove("Hello")
print(s1)
# Out:
# {'Hi', 5, 6, 7, 8}

# %%
s1.union(s2)
print(s1)
# Out:
# {2, 'Hi', 5, 6, 7, 8, 4, 3}

# %%
s1.update(s2)
s1
# Out:
# {2, 3, 4, 5, 6, 7, 8, 'Hi'}

# %%
print(s1)
s1.pop()
s1
# Out:
# {3, 'Hi', 5, 6, 7, 8, 4}
# {4, 5, 6, 7, 8, 'Hi'}
