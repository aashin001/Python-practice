# %%
text = "a\ta\ts\th\ti\tn"

print(text.expandtabs(5))
print(text)
# Out:
# a    a    s    h    i    n
# a	a	s	h	i	n

# %%
print(text.expandtabs(10))
# Out:
# a         a         s         h         i         n
