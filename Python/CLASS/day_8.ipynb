# %%
a = [1, 1, "hi", 1.8, 7.81, True]
# a.replace(1.8,"python")
a[3] ="python"
print(a)
# Out:
# [1, 1, 'hi', 'python', 7.81, True]

# %%
l = ["hi", "2", "Hello", 75]

l[1]=(36)
l.pop(2)
l[2]=(86)
print(l)
# Out:
# ['hi', 36, 86]
