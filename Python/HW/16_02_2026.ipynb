# %%
#list have 10 values
list =["aashin", "r", "nayagam", 23, "MCA", "Jain", "University", "Bangalore", 2025, 73394]
print(list)
# Out:
# ['aashin', 'r', 'nayagam', 23, 'MCA', 'Jain', 'University', 'Bangalore', 2025, 73394]

# %%
#replace second index
list[1] = ("M")
print(list)
# Out:
# ['aashin', 'M', 'nayagam', 23, 'MCA', 'Jain', 'University', 'Bangalore', 2025, 73394]

# %%
list.pop()
print(list)
# Out:
# ['aashin', 'M', 'nayagam', 23, 'MCA', 'Jain', 'University', 'Bangalore', 2025]

# %%
list.append(7339437976)
print(list)
# Out:
# ['aashin', 'M', 'nayagam', 23, 'MCA', 'Jain', 'University', 'Bangalore', 2025, 7339437976]

# %%
list.remove("M")
print(list)
# Out:
# ['aashin', 'nayagam', 23, 'MCA', 'Jain', 'University', 'Bangalore', 2025, 7339437976]
