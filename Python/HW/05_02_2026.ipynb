# %%
#legal Variable

# %%
myname = "aashin"
print(myname)

# %%
_age = 24
print(_age)
# Out:
# 24

# %%
phone_number = 7339437976
print(phone_number)
# Out:
# 7339437976

# %%
EmailID = "aashinmn@gmail.com"
print(EmailID)
# Out:
# aashinmn@gmail.com

# %%
"""Illegal Variable"""

# %%
my name = "aashin"
print(my name)
# Out:
#   Cell In[21], line 1
#     my name = "aashin"
#        ^
# SyntaxError: invalid syntax

# %%
2age = 24
print(2age)
# Out:
#   Cell In[22], line 1
#     2age = 24
#     ^
# SyntaxError: invalid decimal literal

# %%
Phone-number = 7339437976
print(phone-number)
# Out:
#   Cell In[25], line 1
#     Phone-number = 7339437976
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
my_age = input("enter ypur age")
print(my_age)
# Out:
# enter ypur age 24
# 24

# %%
a,b,c, = "aashsin", "f90", "24"
print (b)
# Out:
# f90
