# %%
#arithmatic operators

# %%
a = 20
b = 10

print(a + b) #adds two digits
# Out:
# 30

# %%
print(a-b) #subracting the two digits
# Out:
# 10

# %%
print(a/b) #normal division
# Out:
# 2.0

# %%
print(a//b) #quation of the division
# Out:
# 2

# %%
print(a%b) # reminder of the divison
# Out:
# 0

# %%
print(a*b) # multiplication of the two digits
# Out:
# 200

# %%
print(a**b)# power value of the two digits
# Out:
# 10240000000000

# %%
#assignment operators

# %%
c = 5
c = c+2
print(c)# this is adding assignment by giving the + in the variable
# Out:
# 7

# %%
c = 7
c-=2
print(c) # subract and assign
# Out:
# 5

# %%
c= 5
c*= 5
print(c)#multiply and then assign
# Out:
# 25

# %%
c = 25
c/=2

print(c)# quationt of the division
# Out:
# 12.5

# %%
#comparison operator

# %%
# z = 10 """ its assigning operator"""
# z == 10 """ its comparison operator"""

# %%
z = 10
x = 10

z==x
# Out:
# True

# %%
z != x
# Out:
# False

# %%
z > x
# Out:
# False

# %%
z < x
# Out:
# False

# %%
z >= x
# Out:
# True

# %%
x <= z
# Out:
# True
