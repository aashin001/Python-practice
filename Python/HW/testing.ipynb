# %%
n1 = input("input here").lower()
n2 = input("input here").lower()

if sorted(n1) == sorted(n2):
    print("its anagram")
else:
    print("its not anagram")
# Out:
# input here HannaH
# input here aaNNHh
# its anagram

# %%
pal = input("input: ").lower()

if pal == pal[::-1]:
    print("its a pallindrom")
else:
    print("its not a pallindrom")
# Out:
# input:  Hannah
# its a pallindrom

# %%
pr = int(input("input: "))

for i in range(2, pr):
    if pr % i == 0:
        print("its not a prime")
        break
    else:
        print("its a prime")
# Out:
# input:  4
# its not a prime

# %%
f = int(input("input: "))

f1 = 0
f2 = 1

for q in range(f):
    print(f1, end =" ")

    f3 = f1+f2
    f1 = f2
    f2 = f3
# Out:
# input:  7
# 0 1 1 2 3 5 8

# %%
m = list(map(int, input().split()))

maximum = max(m)
minimum = min(m)

print("maximum: ", maximum)
print("minimum: ", minimum)
# Out:
#  1 2 3 5 4 7 8 9 6 5 2  4 5 8 6 2
# maximum:  9
# minimum:  1

# %%
sl = list(map(int, input().split()))

sl = sorted(sl)

slar = sl[-2]
smin = sl[1]

print("second smallest is: ", smin)
print("second largest is: ", slar)
# Out:
#  11 22 25 4 7 88 7 9 66 6 55 2 2 4  5 4  5
# second smallest is:  2
# second largest is:  66

# %%
asc = list(map(int, input().split()))
asc = list(set(asc))

ascending = sorted(asc)
descending = sorted(asc, reverse = True)

print("asceding: ", ascending, "descending: ", descending)
# Out:
#  1 2 2 33 5 4 77 8 8 8
# asceding:  [1, 2, 4, 5, 8, 33, 77] descending:  [77, 33, 8, 5, 4, 2, 1]

# %%
vc = input("input: ").lower()

if vc in "aeiou":
    print("vowels")
else:
    print("consonents")
# Out:
# input:  a
# vowels

# %%
num = input("input")

print(sum(map(int, num)))
# Out:
# input 23
# 5

# %%
ins = int(input("input: "))

fact = 1

for i in range(1, ins+1):
    fact = fact*i

print("factorial: ", fact)
# Out:
# input:  3
# factorial:  6

# %%
eo = int(input("input: "))

if eo % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# input:  0
# even

# %%
l3 = list(map(int, input().split()))

l3 = list(set(l3))
l3 = sorted(l3)

largest=l3[-1]
print("largest: ", largest)
# Out:
#  12 2 5 47 88 99 6 5 8 77 8 9 6 5 8
# largest:  99

# %%
revs = input("input")

revst = revs[::-1]
print(revst)
# Out:
# input aashin
# nihsaa

# %%
freq = list(map(int, input().split()))

for i in set(freq):
    print(i, " -> ", freq.count(i))
# Out:
#  5 4 6 9 8 7 4 122 5 3 6 5 8 6
# 3  ->  1
# 4  ->  2
# 5  ->  3
# 6  ->  3
# 7  ->  1
# 8  ->  2
# 9  ->  1
# 122  ->  1

# %%
mul = int(input("table: "))

for i in range(0, 11):
    multi = i*mul
    print(i, " x ",mul, " = ", multi)
# Out:
# table:  5
# 0  x  5  =  0
# 1  x  5  =  5
# 2  x  5  =  10
# 3  x  5  =  15
# 4  x  5  =  20
# 5  x  5  =  25
# 6  x  5  =  30
# 7  x  5  =  35
# 8  x  5  =  40
# 9  x  5  =  45
# 10  x  5  =  50

# %%
dup = list(map(int, input().split()))

dup = set(dup)

print(dup)
# Out:
#  1 1 2 3 4 5 6 6 7
# {1, 2, 3, 4, 5, 6, 7}

# %%
m1 = list(map(int, input().split()))
m2 = list(map(int, input().split()))


merged = m1 + m2
merged = set(merged)

sort = sorted(merged)

print(sort)
# Out:
#  1 2 3 3 6
#  2 3 7 8 9 7
# [1, 2, 3, 6, 7, 8, 9]

# %%
lp = int(input(" Enter the year: "))

if (lp % 4 == 0 and lp % 100 != 0) or (lp % 400 == 0):
    print("its a leap year")

else:
    print("its not leap year")
# Out:
#  Enter the year:  4200
# its not leap year
