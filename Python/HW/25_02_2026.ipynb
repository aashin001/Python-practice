# %% [markdown]
#  SECTION A

# %% [markdown]
# A1

# %%
a = int(input("enter a number"))
if a % 2== 0:
    print("the number is even")
else:
    print("odd")
# Out:
# enter a number 54598
# the number is even

# %% [markdown]
# A2

# %%
grade = float(input("enter the marks here"))
if grade >= 90:
    print("grade A")
elif grade >= 80:
    print("grade B")
elif grade >= 65:
    print("grade C")
elif grade >= 45:
    print("grade D")
else:
    print("Fail")
# Out:
# enter the marks here 21.5
# Fail

# %% [markdown]
# A3

# %%
num = int(input("Enter a  number"))
if num > 0:
    print("postive")
elif num < 0:
    print("Negative")
else:
    print("its 0")
# Out:
# Enter a  number -1
# Negative

# %% [markdown]
# A4

# %% [markdown]
# A5

# %%
a1 = int(input("Enter Number 1 :"))
a2 = int(input("Enter Number 2 :"))
a3 = int(input("Enter Number 3 :"))

print("Small number from the three :", min(a1,a2,a3))
# Out:
# Enter Number 1 : 24
# Enter Number 2 : 26
# Enter Number 3 : 25
# Small number from the three : 24

# %% [raw]
# A6 Create a Password Validator (Password: Python123)

# %%
passw = input("Enter a password")

if passw == "Python123" :
    print("password Granted")
else:
    print("password rejected")
# Out:
# Enter a password python123
# password rejected

# %% [markdown]
# A7. Create a Simple Calculator using +, -, *, /

# %% [raw]
# num1 = float(input("enter a number"))
# op = input("operations +,-,*,/")
# num2 = float(input("enter a number"))
#
# if op == "+":
#     print( num1 + num2 )
# elif op == "-":
#     print(num1 - num2 )
# elif op == "*":
#     print(num1 * num2)
# elif op == "/":
#     if num2 != 0:
#         print( num1 / num2)
#     else:
#         print(" cannot divide by 0")
# else:
#     print("invalid input")

# %% [markdown]
# A8. Write a program to check Voting Eligibility (age >= 18)

# %%
age = int(input("Enter your age : "))
if age >= 18:
    print("You are eligible for vote")
else:
    print("you are not eligible for vote")
# Out:
# Enter your age :  18
# You are eligible for vote

# %% [markdown]
# A9. Write a program to check Character Type (Vowel/Consonant/Other)

# %%
ch = input("Enter a charachter").lower()

if ch in "aeiou":
    print("vowles")
elif ch.isalpha():
    print("consonents")
else:
    print("others")
# Out:
# Enter a charachter U
# vowles

# %% [markdown]
# A10. Write a program to check Weekend or Weekday

# %%
week = input("Enter a day in week").lower()
if week in ["saturday","sunday"]:
    print("weekend")
else:
    print("weekday")
# Out:
# Enter a day in week Saturday
# weekend

# %% [markdown]
# SECTION B – List Operations

# %%
l = [1,22,3,44,55,6,11,1200]

# %% [markdown]
# B1. Insert 4 at 6th index.

# %%
l.insert(4, 6)
print(l)
# Out:
# [1, 22, 3, 44, 6, 55, 6, 11, 1200]

# %% [markdown]
# B2. Remove value 44

# %%
l.remove(44)
l
# Out:
# [1, 22, 3, 6, 55, 6, 11, 1200]

# %% [markdown]
# B3. Append 88

# %%
l.append(88)
l
# Out:
# [1, 22, 3, 6, 55, 6, 11, 1200, 88]

# %% [markdown]
# B4. Remove element at 2nd index.

# %%
l.pop(1)
l
# Out:
# [1, 3, 6, 55, 6, 11, 1200, 88]

# %% [markdown]
# B5. Merge m = [1, 2, 3, 546] with l.

# %%
m = [1,2,3,546]
l.extend(m)
l
# Out:
# [1, 3, 6, 55, 6, 11, 1200, 88, 1, 2, 3, 546]

# %% [markdown]
# SECTION C – String Operations

# %%
s = "HelloWorld"

# %% [markdown]
# C1. Insert "Python" at 6th index.

# %% [markdown]
# C2. Remove "World".

# %%
s= s.replace("World","")
s
# Out:
# 'Hello'

# %% [markdown]
# C3. Append "2024".

# %%
s= s + "2024"
s
# Out:
# 'Hello2024'

# %% [markdown]
# C4. Remove character at 2nd index

# %%
s = s[:2] + s[3:]
s
# Out:
# 'Helo2024'

# %% [markdown]
# C5.Concatenate t = "Programming"

# %%
t = "programming"
s= s+t
s
# Out:
# 'Helo2024programming'

# %% [markdown]
# SECTION D – Programs with Sample Input & Output

# %% [markdown]
# D3. Simple Login System (Username: admin, Password: 1234)

# %%
username = input("Enter your username : ")
password = input("Enter your password : ")

if username == "admin" and password == "1234":
    print("Successfully login in")
else:
    print("Password is Error Please try again")
# Out:
# Enter your username :  admin
# Enter your password :  1234
# Successfully login in
