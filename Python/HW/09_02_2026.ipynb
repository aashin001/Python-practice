# %%
a = "aashin nayagam"
print(a.title()) # title gives each first letter capital
# Out:
# Aashin Nayagam

# %%
textt = "aashin"
print(textt.isalpha()) # checking only for alphabets
# Out:
# True

# %%
print(textt.isdigit()) # checking only for numbers
# Out:
# False

# %%
mail = "aashinmn@gmail.com"
print(mail.startswith("aashin")) # here it checks whether the starting is with aashin
# Out:
# True

# %%
form = "my name is {}"
print(form.format("aashin"))# here in the curlyBraces the aashin format havce been take place
# Out:
# my name is aashin

# %%
en ="python"
print(en.encode()) # byte objects
# Out:
# b'python'

# %%
z = input("enter your name")
x = input("enter youe phone number")

ans = f" my name is {z} and my mobile number is {x}"
print(ans)
# Out:
# enter your name aashin
# enter youe phone number 78
#  my name is aashin and my mobile number is 78
