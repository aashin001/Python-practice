# %%
age = 24  # number is int
print(type(age))
# Out:
# <class 'int'>

# %%
price = 100.50  # this number is decimal which is float
print(type(price))
# Out:
# <class 'float'>

# %%
product_name = "carbon fiber"  #this is set to be a string
print(type(product_name))
# Out:
# <class 'str'>

# %%
paid = True  # True or False are set to be boolean
print(type(paid))
# Out:
# <class 'bool'>

# %%
formula_used = 21+11j  # value + valuej is set to be a complex
print(type(formula_used))
# Out:
# <class 'complex'>

# %%
CASTING

# %%
age2 = float(age)  
print(age2)
# now the age which is int have been change to float and diclared with decimal value
# Out:
# 24.0

# %%
price2 = int(price)
print(price2)
# here the float value have been changed to integer
# Out:
# 100

# %%
product_name2 = complex(product_name)
print(product_name)
#  here the string value cant be change to the complex so it was a error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 product_name2 = complex(product_name)
#       2 print(product_name)
#
# ValueError: complex() arg is a malformed string

# %%
paid2 = str(paid)
print(paid)
#  here the boolean have been changes to string so that the True have been declared
# Out:
# True

# %%
formula_used2 = str(formula_used)
print(formula_used)
# here also the same concept as the above one like the complex have been changed to string and its printed
# Out:
# (21+11j)
